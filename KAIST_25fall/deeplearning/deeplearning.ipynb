# %% [markdown]
# ### 분석 내용 설명
# - 참고한 논문: "Hybrid Forecast of S&P 500 Volatility ensembled from VIX, GARCH and LSTM models" (https://arxiv.org/abs/2407.16780)
# - 분석 목표는 아래와 같다
# -   지수의 실현 변동성을 예측해본다
# -   이때 LSTM 모델을 활용한다
# - 비교하는 모델은 총 세가지로 아래와 같다
#     - LSTM
#         - 입력 정보:
#             - 가격 정보(SPX 로그수익률)
#             - lagged realized volatility (가격 기반 파생 변수)
#     - LSTM-GARCH
#         - 입력 정보:
#             - 가격 정보(SPX 로그수익률)
#             - lagged realized volatility (가격 기반 파생 변수)
#             - GARCH(2,2) 예측 변동성 단기 변동성에 대한 추가 정보를 포함
#             - GARCH(2,2) 모델로 선택한 이유는 참고한 논문에서 해당 모형이 SPX 변동성 예측에 가장 정확도가 높았다고 명시했기 때문
#     - Hybrid (LSTM-GARCH + VIX):
#         - 입력 정보:
#             - 가격 정보(SPX 로그수익률)
#             - lagged realized volatility (가격 기반 파생 변수)
#             - GARCH(2,2) 예측 변동성
#             - VIX 지수 : 앞으로 30일 동안의 기대 변동성 정보를 포함
#
# - LSTM 모델 구조는 세가지 모두 통일
# - 2층 LSTM으로 각 층당 , 128 유닛, 드롭아웃은 0.1로 설정
#   - 1. LSTM(128 units, `tanh`, `return_sequences=True`)
#     - 하나의 입력은 22개의 시계열 관측치로 구성 (룩백 윈도우=22)
#     - 각 입력에 대해 128개의 특징으로 요약하도록 구성
#       - 128 개의 특징으로 설정할 경우, 시계열의 복잡한 패턴을 충분히 학습할 수 있다고 알려져 있기 때문 (논문 참고)
#     - 총 22 * 128 크기의 출력을 생성
#     - LSTM gate 로 `tanh' activation 함수를 사용했는데 이는 시계열 데이터에서 일반적으로 좋은 성능을 보이기 때문 (논문 참고)
#     - 오버피팅을 방지하기 위해서, 0.1의 드롭아웃 적용
#   - 2. LSTM(128 units, `tanh`, `return_sequences=False`)
#     - 첫 번째 LSTM 층의 출력을 입력으로 받아서, 시계열 특징을 더 추출
#     - 128개의 특징으로 요약된 벡터를 출력
#     - 오버피팅 방지를 위해서, 0.1의 드롭아웃 적용
# - 마지막 출력층에서 Relu 활성화 함수를 사용 128개의 특징을 하나의 변동성 값으로 추출
#     - 변동성은 음수가 될 수 없기 떄문에, 출력값을 0이상으로 하기 위해 ReLu를 사용
# - 모델 예측 시,EarlyStopping을 적용하여, Val_loss가 10 epoch(회) 동안 개선되지 않으면 가장 성능이 좋았던 weights으로 복원하도록 설정하였음
#
# - 각 모델에서 사용하는 feature는 다음과 같다
#     - LSTM: ["ret", "lag_realized_vol"]
#     - LSTM-GARCH: ["ret", "lag_realized_vol", "garch_vol"]
#     - Hybrid (LSTM-GARCH + VIX): ["ret", "lag_realized_vol", "garch_vol", "vix"]
#
# - Test, Validation 기간: 2020-01-01 ~ 2024-12-31
# - Train 70%, Val 15%, Test 15% 로 대략 2년치의 데이터를 예측하도록 함
# - 평가 지표: RMSE, MAE이며, 예측한 변동성과, 실제 변동성(realized_vol) 간의 오차를 시각화
#
# - 결과: Hybrid (LSTM-GARCH + VIX) 모델이 가장 낮은 MAE와 RMSE를 보이지만, MAE 기준 0.0001 수준의 미미한 차이로 가격 정보를 활용하여 LSTM만으로 예측한 것이도 상당히 좋은 성능을 보임
# - 실제 변동성은 평균 0.0103 이며, 위기 시에는 0.06까지도 상승하는 것으로 확인되는데 0.0001 수준의 오차는 매우 작은 수준으로 확인되어 예측력은 충분히 높은 것으로 판단됨

# %%
#/*****************************************
 # * 0. 라이브러리와 기본 설정 값 가져오기 *
 # *****************************************/

import numpy as np
import pandas as pd

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

from arch import arch_model

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
tf.keras.utils.set_random_seed(4035)
tf.config.experimental.enable_op_determinism()

import yfinance as yf

np.random.seed(4035)
tf.random.set_seed(4035)

# %%
# ================================
#   파생 변수 생성
#   - log return
#   - 22일 realized volatility
#   - lag volatility
# ================================


spx_ticker="^GSPC"
vix_ticker="^VIX"
start="2000-01-01"
end="2024-12-31"

spx = yf.download(spx_ticker, start=start, end=end)
vix = yf.download(vix_ticker, start=start, end=end)

# print(spx.head())
# print(vix.head())

# 1) 'Close' 레벨에서 첫 번째 컬럼(=그 티커)만 Series로 뽑기
spx_close = spx["Close"].iloc[:, 0]   # (N, ) Series
vix_close = vix["Close"].iloc[:, 0]   # (N, ) Series

# 2) 이름 붙이기
spx_close = spx_close.rename("SPX")
vix_close = vix_close.rename("VIX")

# 3) 옆으로 붙이기
df = pd.concat([spx_close, vix_close], axis=1).dropna()
print(df.head())
print(df.shape)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_3284\3100527890.py:14: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   spx = yf.download(spx_ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
# C:\Users\User\AppData\Local\Temp\ipykernel_3284\3100527890.py:15: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   vix = yf.download(vix_ticker, start=start, end=end)
# [*********************100%***********************]  1 of 1 completed
#                     SPX        VIX
# Date
# 2000-01-03  1455.219971  24.209999
# 2000-01-04  1399.420044  27.010000
# 2000-01-05  1402.109985  26.410000
# 2000-01-06  1403.449951  25.730000
# 2000-01-07  1441.469971  21.719999
# (6288, 2)

# %%
# ================================
# 2. 파생 변수 생성
#    - log return
#    - 22일 realized volatility
#    - lag volatility
# ================================
vol_window = 22 
df['ret'] = np.log(df['SPX']/df['SPX'].shift(1))
df['realized_vol'] = df['ret'].rolling(window=vol_window).std()
df['lag_realized_vol'] = df['realized_vol'].shift(1)
df = df.dropna()
print(df.head())
print(df.isna().sum())
print(df['realized_vol'].describe())
# Out:
#                     SPX        VIX       ret  realized_vol  lag_realized_vol
# Date
# 2000-02-04  1424.369995  21.540001 -0.000421      0.013582          0.016031
# 2000-02-07  1424.239990  22.790001 -0.000091      0.013581          0.013582
# 2000-02-08  1441.719971  21.250000  0.012198      0.013801          0.013581
# 2000-02-09  1411.709961  22.900000 -0.021035      0.013346          0.013801
# 2000-02-10  1416.829956  23.070000  0.003620      0.013117          0.013346
# SPX                 0
# VIX                 0
# ret                 0
# realized_vol        0
# lag_realized_vol    0
# dtype: int64
# count    6265.000000
# mean        0.010335
# std         0.006669
# min         0.002164
# 25%         0.006196
# 50%         0.008620
# 75%         0.012603
# max         0.060027
# Name: realized_vol, dtype: float64

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(5, 1, figsize=(10, 15), sharex=True)
axs[0].plot(df.index, df['SPX'])
axs[0].set_title('S&P 500 Index')
axs[1].plot(df.index, df['VIX'], color='orange')
axs[1].set_title('VIX Index')
axs[2].plot(df.index, df['ret'], color='green')
axs[2].set_title('Log Returns')
axs[3].plot(df.index, df['realized_vol'], color='red')
axs[3].set_title('22-Day Realized Volatility')
axs[4].plot(df.index, df['lag_realized_vol'], color='purple')
axs[4].set_title('Lagged Realized Volatility')
plt.tight_layout()
plt.show()

# %%
returns = df["ret"].dropna()
dates = returns.index
garch_forecasts = pd.Series(index=dates, dtype=float)

p, q = 2, 2 # GARCH(2,2) 모델 적용 
initial_window = 1500  

if len(returns) <= initial_window + 1:
    raise ValueError(f"initial_window={initial_window} 이(가) 너무 큼. "
                     f"returns 길이={len(returns)} 확인해서 줄여줘.")

print("GARCH is rolling..")
for i in range(initial_window, len(returns) - 1):
    train_data = returns.iloc[:i]

    am = arch_model(
        train_data * 100, 
        mean="Zero",
        vol="GARCH",
        p=p,
        q=q,
        dist="normal",
    )
    res = am.fit(disp="off")

    forecast = res.forecast(horizon=1)
    sigma2_t1 = forecast.variance.values[-1, 0]

    garch_forecasts.iloc[i + 1] = np.sqrt(sigma2_t1)

print("GARCH forcast count:", garch_forecasts.notna().sum())

garch_forecasts.name = "garch_vol_pred"

# df에 merge 해서, LSTM feature로 사용 준비 
df = df.join(garch_forecasts, how="left")
df = df.dropna()
print("GARCH 예측 merge 후 데이터 크기:", df.shape)
print(df[["ret", "realized_vol", "lag_realized_vol", "garch_vol_pred", "VIX"]].head())
# Out:
# GARCH is rolling..
# GARCH forcast count: 4764
# GARCH 예측 merge 후 데이터 크기: (4764, 6)
#                  ret  realized_vol  lag_realized_vol  garch_vol_pred    VIX
# Date
# 2006-01-26  0.007209      0.006985          0.006870        0.740898  12.42
# 2006-01-27  0.007734      0.007168          0.006985        0.739181  11.97
# 2006-01-30  0.001144      0.006801          0.007168        0.715838  12.39
# 2006-01-31 -0.003984      0.006883          0.006801        0.733648  12.95
# 2006-02-01  0.001858      0.006834          0.006883        0.723744  12.36

# %% [markdown]
# ### Model 1: Predict Realized Volatility using Only LSTM

# %%
# ================================
# 4. LSTM용 데이터셋 만들기
#    - feature: ret, lag_realized_vol 
#    - target: realized_vol
#    - 시퀀스: lookback 길이
# ================================

feature_cols = ["ret", "lag_realized_vol"]  
target_col = "realized_vol"
lookback = 22

data = df.copy()

X_raw = data[feature_cols].values
y_raw = data[target_col].values.reshape(-1, 1)

# %%
# ================================
# 5. train / val / test 분할
# ================================

n = len(X_raw)
n_train = int(n * 0.7)
n_val = int(n * 0.15)

X_raw_train = X_raw[:n_train]
X_raw_val   = X_raw[n_train:n_train + n_val]
X_raw_test  = X_raw[n_train + n_val:]

y_raw_train = y_raw[:n_train]
y_raw_val   = y_raw[n_train:n_train + n_val]
y_raw_test  = y_raw[n_train + n_val:]

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_raw_train)
y_train_scaled = scaler_y.fit_transform(y_raw_train)

X_val_scaled   = scaler_X.transform(X_raw_val)
y_val_scaled   = scaler_y.transform(y_raw_val)

X_test_scaled  = scaler_X.transform(X_raw_test)
y_test_scaled  = scaler_y.transform(y_raw_test)

# Train
X_train_list = []
y_train_list = []
for i in range(lookback, len(X_train_scaled)):
    X_train_list.append(X_train_scaled[i - lookback:i])
    y_train_list.append(y_train_scaled[i, 0])
X_train = np.array(X_train_list)
y_train = np.array(y_train_list)

# Val
X_val_list = []
y_val_list = []
for i in range(lookback, len(X_val_scaled)):
    X_val_list.append(X_val_scaled[i - lookback:i])
    y_val_list.append(y_val_scaled[i, 0])
X_val = np.array(X_val_list)
y_val = np.array(y_val_list)

# Test
X_test_list = []
y_test_list = []
for i in range(lookback, len(X_test_scaled)):
    X_test_list.append(X_test_scaled[i - lookback:i])
    y_test_list.append(y_test_scaled[i, 0])
X_test = np.array(X_test_list)
y_test = np.array(y_test_list)


print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape, y_val.shape)
print("Test :", X_test.shape, y_test.shape)
# Out:
# Train: (3312, 22, 2) (3312,)
# Val  : (692, 22, 2) (692,)
# Test : (694, 22, 2) (694,)

# %%
# ================================
# 6. LSTM 모델 정의 & 학습
# ================================

input_shape = X_train.shape[1:]  # (lookback, n_features)
print("LSTM 입력 형태:", input_shape)

param_options=[
    {"units": 64 , "dropout": 0.1, "lr": 0.001},
    {"units": 128, "dropout": 0.1, "lr": 0.001},
    {"units": 128, "dropout": 0.2, "lr": 0.001},
    {"units": 128, "dropout": 0.1, "lr": 0.0005},
]

# lstm_units = 128
# num_layers = 2
# dropout_rate = 0.1

best_val_loss_1 = np.inf
best_cfg_1 = None
best_model_1 = None

for i, cfg in enumerate(param_options, start=1):
    print(f"\n=== Trial {i}: {cfg} ===")
    lstm_units = cfg["units"]
    dropout_rate = cfg["dropout"]
    learning_rate = cfg["lr"]
    num_layers = 2

    model = models.Sequential()
    # 첫 번째 LSTM
    model.add(
        layers.LSTM(
            cfg["units"],
            activation="tanh",
            return_sequences=(num_layers > 1),
            input_shape=input_shape,
        )
    )
    model.add(layers.Dropout(cfg["dropout"]))

    # 두 번째 LSTM (num_layers=2 기준)
    model.add(
        layers.LSTM(
            cfg["units"],
            activation="tanh",
            return_sequences=False,
        )
    )
    model.add(layers.Dropout(cfg["dropout"]))

    # 출력층
    model.add(layers.Dense(1, activation="relu"))
    # Relu를 사용함으로써 0 이상으로 나오도록 강제 및 선형적으로 숫자가 커짐으로써 큰 변동성 spike도 잡아내도록 

    model.compile(
        loss="mse",
        optimizer=tf.keras.optimizers.Adam(learning_rate=cfg["lr"]),
    )

    print(model.summary())

    es = callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
    )

    history = model.fit(
        X_train,
        y_train,
        validation_data=(X_val, y_val),
        epochs=100,
        batch_size=64,
        shuffle=False,
        callbacks=[es],
        verbose=1,
    )
    val_loss = min(history.history["val_loss"])
    print(f"optimal loss: {val_loss:.6f}")

    if val_loss < best_val_loss_1:
        best_val_loss_1 = val_loss
        best_cfg_1 = cfg
        best_model_1 = model
    
print(f"\n=== best model: {best_cfg_1}, val loss: {best_val_loss_1:.6f} ===")
# Out:
# LSTM 입력 형태: (22, 2)
#
# === Trial 1: {'units': 64, 'dropout': 0.1, 'lr': 0.001} ===
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 22, 64)         │        17,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 22, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,241 (196.25 KB)
#  Trainable params: 50,241 (196.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 35ms/step - loss: 0.0139 - val_loss: 0.0132
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0057 - val_loss: 0.0080
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0025 - val_loss: 0.0068
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0020 - val_loss: 0.0055
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0018 - val_loss: 0.0042
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 0.0015 - val_loss: 0.0029
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0013 - val_loss: 0.0023
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0010 - val_loss: 0.0019
# Epoch 12/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 9.4772e-04 - val_loss: 0.0017
# Epoch 13/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 9.4221e-04 - val_loss: 0.0016
# Epoch 14/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 8.8497e-04 - val_loss: 0.0016
# Epoch 15/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 8.6284e-04 - val_loss: 0.0015
# Epoch 16/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 8.1695e-04 - val_loss: 0.0014
# Epoch 17/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 8.4759e-04 - val_loss: 0.0014
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 7.5463e-04 - val_loss: 0.0014
# Epoch 19/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 7.1952e-04 - val_loss: 0.0014
# Epoch 20/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 7.2238e-04 - val_loss: 0.0013
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 7.5393e-04 - val_loss: 0.0013
# Epoch 22/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 6.8096e-04 - val_loss: 0.0013
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 6.6478e-04 - val_loss: 0.0013
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 7.3811e-04 - val_loss: 0.0013
# Epoch 25/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 6.5291e-04 - val_loss: 0.0012
# Epoch 26/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 6.8538e-04 - val_loss: 0.0012
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.4249e-04 - val_loss: 0.0012
# Epoch 28/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.5730e-04 - val_loss: 0.0012
# Epoch 29/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 6.4167e-04 - val_loss: 0.0012
# Epoch 30/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.4994e-04 - val_loss: 0.0011
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.5802e-04 - val_loss: 0.0011
# Epoch 32/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 5.9129e-04 - val_loss: 0.0011
# Epoch 33/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.3661e-04 - val_loss: 0.0011
# Epoch 34/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 6.3120e-04 - val_loss: 0.0011
# Epoch 35/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.7230e-04 - val_loss: 0.0011
# Epoch 36/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.5975e-04 - val_loss: 0.0011
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 6.1662e-04 - val_loss: 0.0011
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.9035e-04 - val_loss: 0.0010
# Epoch 39/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 5.5652e-04 - val_loss: 0.0011
# Epoch 40/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.4690e-04 - val_loss: 0.0011
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.0741e-04 - val_loss: 0.0010
# Epoch 42/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.6773e-04 - val_loss: 0.0010
# Epoch 43/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.1062e-04 - val_loss: 0.0010
# Epoch 44/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 5.8262e-04 - val_loss: 9.8150e-04
# Epoch 45/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.5701e-04 - val_loss: 9.7333e-04
# Epoch 46/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.6602e-04 - val_loss: 9.9195e-04
# Epoch 47/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.5305e-04 - val_loss: 9.7293e-04
# Epoch 48/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 5.3982e-04 - val_loss: 9.1973e-04
# Epoch 49/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 5.2677e-04 - val_loss: 9.2558e-04
# Epoch 50/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.0087e-04 - val_loss: 9.2194e-04
# Epoch 51/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.3177e-04 - val_loss: 9.9854e-04
# Epoch 52/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 6.3231e-04 - val_loss: 9.4943e-04
# Epoch 53/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.0117e-04 - val_loss: 9.2355e-04
# Epoch 54/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 5.0343e-04 - val_loss: 8.7807e-04
# Epoch 55/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.3537e-04 - val_loss: 9.1614e-04
# Epoch 56/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.3769e-04 - val_loss: 8.8395e-04
# Epoch 57/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.2613e-04 - val_loss: 8.8885e-04
# Epoch 58/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.8237e-04 - val_loss: 8.3101e-04
# Epoch 59/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.0728e-04 - val_loss: 8.3265e-04
# Epoch 60/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.5239e-04 - val_loss: 8.3850e-04
# Epoch 61/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.1009e-04 - val_loss: 8.2677e-04
# Epoch 62/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.0879e-04 - val_loss: 8.1829e-04
# Epoch 63/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.8848e-04 - val_loss: 7.9668e-04
# Epoch 64/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.7498e-04 - val_loss: 7.8859e-04
# Epoch 65/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.7829e-04 - val_loss: 8.1544e-04
# Epoch 66/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.3682e-04 - val_loss: 8.1347e-04
# Epoch 67/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.1235e-04 - val_loss: 7.8260e-04
# Epoch 68/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 4.7626e-04 - val_loss: 7.5840e-04
# Epoch 69/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.4930e-04 - val_loss: 7.5795e-04
# Epoch 70/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.6180e-04 - val_loss: 7.6515e-04
# Epoch 71/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.1048e-04 - val_loss: 8.1197e-04
# Epoch 72/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.7898e-04 - val_loss: 7.4916e-04
# Epoch 73/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.5874e-04 - val_loss: 7.3044e-04
# Epoch 74/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 3.9814e-04 - val_loss: 7.4433e-04
# Epoch 75/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.5849e-04 - val_loss: 7.6416e-04
# Epoch 76/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.6203e-04 - val_loss: 7.1475e-04
# Epoch 77/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.3203e-04 - val_loss: 7.3883e-04
# Epoch 78/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.5962e-04 - val_loss: 7.1549e-04
# Epoch 79/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.2584e-04 - val_loss: 6.8983e-04
# Epoch 80/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.1548e-04 - val_loss: 6.9006e-04
# Epoch 81/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.1160e-04 - val_loss: 7.3197e-04
# Epoch 82/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.5749e-04 - val_loss: 7.3252e-04
# Epoch 83/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 4.2348e-04 - val_loss: 6.8329e-04
# Epoch 84/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - loss: 4.0448e-04 - val_loss: 6.7041e-04
# Epoch 85/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.1206e-04 - val_loss: 6.7600e-04
# Epoch 86/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.3132e-04 - val_loss: 6.7334e-04
# Epoch 87/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.3421e-04 - val_loss: 7.3760e-04
# Epoch 88/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.4940e-04 - val_loss: 6.8837e-04
# Epoch 89/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.2545e-04 - val_loss: 6.2553e-04
# Epoch 90/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.2658e-04 - val_loss: 7.0416e-04
# Epoch 91/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.6887e-04 - val_loss: 6.2343e-04
# Epoch 92/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.9199e-04 - val_loss: 6.9666e-04
# Epoch 93/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.7504e-04 - val_loss: 6.5160e-04
# Epoch 94/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.9496e-04 - val_loss: 6.2364e-04
# Epoch 95/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.1236e-04 - val_loss: 6.5133e-04
# Epoch 96/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.2464e-04 - val_loss: 6.7070e-04
# Epoch 97/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.7160e-04 - val_loss: 6.1335e-04
# Epoch 98/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 3.8422e-04 - val_loss: 5.9687e-04
# Epoch 99/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.8228e-04 - val_loss: 6.0194e-04
# Epoch 100/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 3.5801e-04 - val_loss: 5.9063e-04
# optimal loss: 0.000591
#
# === Trial 2: {'units': 128, 'dropout': 0.1, 'lr': 0.001} ===
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 22, 128)        │        67,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 22, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 198,785 (776.50 KB)
#  Trainable params: 198,785 (776.50 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - loss: 0.0386 - val_loss: 0.0620
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step - loss: 0.0388 - val_loss: 0.0620
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0388 - val_loss: 0.0620
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0388 - val_loss: 0.0620
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0388 - val_loss: 0.0620
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0388 - val_loss: 0.0620
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0388 - val_loss: 0.0620
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0388 - val_loss: 0.0620
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0388 - val_loss: 0.0620
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 0.0388 - val_loss: 0.0620
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0388 - val_loss: 0.0620
# optimal loss: 0.062041
#
# === Trial 3: {'units': 128, 'dropout': 0.2, 'lr': 0.001} ===
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 22, 128)        │        67,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 22, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 198,785 (776.50 KB)
#  Trainable params: 198,785 (776.50 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - loss: 0.0112 - val_loss: 0.0122
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0041 - val_loss: 0.0066
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0020 - val_loss: 0.0048
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0015 - val_loss: 0.0034
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0015 - val_loss: 0.0026
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0012 - val_loss: 0.0021
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0010 - val_loss: 0.0017
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 9.2355e-04 - val_loss: 0.0016
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 9.2500e-04 - val_loss: 0.0015
# Epoch 12/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 7.6703e-04 - val_loss: 0.0015
# Epoch 13/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 8.8725e-04 - val_loss: 0.0015
# Epoch 14/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 8.1715e-04 - val_loss: 0.0014
# Epoch 15/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 8.0244e-04 - val_loss: 0.0014
# Epoch 16/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 7.7771e-04 - val_loss: 0.0014
# Epoch 17/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 6.8527e-04 - val_loss: 0.0013
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 7.7115e-04 - val_loss: 0.0013
# Epoch 19/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 7.0434e-04 - val_loss: 0.0013
# Epoch 20/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 8.0780e-04 - val_loss: 0.0013
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 7.0887e-04 - val_loss: 0.0013
# Epoch 22/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 6.8969e-04 - val_loss: 0.0012
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 7.4199e-04 - val_loss: 0.0012
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 7.5185e-04 - val_loss: 0.0012
# Epoch 25/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 6.8019e-04 - val_loss: 0.0012
# Epoch 26/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 6.0959e-04 - val_loss: 0.0012
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 6.9482e-04 - val_loss: 0.0012
# Epoch 28/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 6.8316e-04 - val_loss: 0.0011
# Epoch 29/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 6.6862e-04 - val_loss: 0.0012
# Epoch 30/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 7.7538e-04 - val_loss: 0.0012
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.2339e-04 - val_loss: 0.0011
# Epoch 32/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 6.5690e-04 - val_loss: 0.0011
# Epoch 33/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 6.0427e-04 - val_loss: 0.0011
# Epoch 34/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.7180e-04 - val_loss: 0.0011
# Epoch 35/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 5.7548e-04 - val_loss: 0.0010
# Epoch 36/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 5.6338e-04 - val_loss: 0.0010
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.7438e-04 - val_loss: 0.0010
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.3354e-04 - val_loss: 9.5683e-04
# Epoch 39/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step - loss: 5.1951e-04 - val_loss: 9.8830e-04
# Epoch 40/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 5.5205e-04 - val_loss: 9.3054e-04
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 31ms/step - loss: 5.5508e-04 - val_loss: 9.9659e-04
# Epoch 42/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 5.5565e-04 - val_loss: 9.9381e-04
# Epoch 43/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.6148e-04 - val_loss: 9.1752e-04
# Epoch 44/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.9308e-04 - val_loss: 9.6098e-04
# Epoch 45/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.9312e-04 - val_loss: 0.0012
# Epoch 46/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 7.3873e-04 - val_loss: 0.0011
# Epoch 47/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.4681e-04 - val_loss: 0.0010
# Epoch 48/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.2849e-04 - val_loss: 9.4861e-04
# Epoch 49/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.6588e-04 - val_loss: 9.0406e-04
# Epoch 50/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 76ms/step - loss: 5.3898e-04 - val_loss: 8.9041e-04
# Epoch 51/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 4.9612e-04 - val_loss: 8.5038e-04
# Epoch 52/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 5.3503e-04 - val_loss: 8.7047e-04
# Epoch 53/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.7219e-04 - val_loss: 8.2301e-04
# Epoch 54/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 5.1383e-04 - val_loss: 8.9046e-04
# Epoch 55/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 5.4759e-04 - val_loss: 9.2206e-04
# Epoch 56/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 5.1149e-04 - val_loss: 8.7520e-04
# Epoch 57/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.0569e-04 - val_loss: 8.5624e-04
# Epoch 58/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.7994e-04 - val_loss: 9.0814e-04
# Epoch 59/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 5.3958e-04 - val_loss: 8.2699e-04
# Epoch 60/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.1369e-04 - val_loss: 8.6135e-04
# Epoch 61/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 4.6758e-04 - val_loss: 9.0020e-04
# Epoch 62/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 5.3492e-04 - val_loss: 7.7690e-04
# Epoch 63/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.7093e-04 - val_loss: 7.9071e-04
# Epoch 64/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.2569e-04 - val_loss: 9.0326e-04
# Epoch 65/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 6.6710e-04 - val_loss: 7.5945e-04
# Epoch 66/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.3144e-04 - val_loss: 7.8796e-04
# Epoch 67/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.0911e-04 - val_loss: 7.3777e-04
# Epoch 68/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 5.0512e-04 - val_loss: 7.4758e-04
# Epoch 69/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 4.9499e-04 - val_loss: 7.3266e-04
# Epoch 70/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.0623e-04 - val_loss: 7.2979e-04
# Epoch 71/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.6556e-04 - val_loss: 7.3927e-04
# Epoch 72/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 4.9746e-04 - val_loss: 7.1681e-04
# Epoch 73/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 72ms/step - loss: 4.4833e-04 - val_loss: 6.7980e-04
# Epoch 74/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.8003e-04 - val_loss: 7.1600e-04
# Epoch 75/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.0555e-04 - val_loss: 6.6858e-04
# Epoch 76/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.2507e-04 - val_loss: 7.5961e-04
# Epoch 77/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 4.5248e-04 - val_loss: 6.5051e-04
# Epoch 78/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 3.9828e-04 - val_loss: 7.0716e-04
# Epoch 79/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 4.9166e-04 - val_loss: 6.8484e-04
# Epoch 80/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.1277e-04 - val_loss: 6.4295e-04
# Epoch 81/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 4.2719e-04 - val_loss: 6.2487e-04
# Epoch 82/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.1770e-04 - val_loss: 6.7699e-04
# Epoch 83/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 4.0726e-04 - val_loss: 6.7762e-04
# Epoch 84/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.3105e-04 - val_loss: 8.4335e-04
# Epoch 85/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 5.2753e-04 - val_loss: 7.3607e-04
# Epoch 86/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.2044e-04 - val_loss: 8.8588e-04
# Epoch 87/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 6.7095e-04 - val_loss: 7.0338e-04
# Epoch 88/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.3543e-04 - val_loss: 7.4771e-04
# Epoch 89/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.3810e-04 - val_loss: 6.5438e-04
# Epoch 90/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 4.2202e-04 - val_loss: 6.9125e-04
# Epoch 91/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.4777e-04 - val_loss: 6.5185e-04
# optimal loss: 0.000625
#
# === Trial 4: {'units': 128, 'dropout': 0.1, 'lr': 0.0005} ===
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_6 (LSTM)                   │ (None, 22, 128)        │        67,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 22, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 198,785 (776.50 KB)
#  Trainable params: 198,785 (776.50 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 9s 80ms/step - loss: 0.0133 - val_loss: 0.0143
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 80ms/step - loss: 0.0062 - val_loss: 0.0088
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 73ms/step - loss: 0.0030 - val_loss: 0.0078
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 67ms/step - loss: 0.0022 - val_loss: 0.0065
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 0.0020 - val_loss: 0.0054
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 70ms/step - loss: 0.0017 - val_loss: 0.0041
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 0.0015 - val_loss: 0.0032
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.0012 - val_loss: 0.0026
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 63ms/step - loss: 0.0012 - val_loss: 0.0024
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.0011 - val_loss: 0.0023
# Epoch 12/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 0.0010 - val_loss: 0.0022
# Epoch 13/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 9.9072e-04 - val_loss: 0.0020
# Epoch 14/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 9.1637e-04 - val_loss: 0.0020
# Epoch 15/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 71ms/step - loss: 9.4451e-04 - val_loss: 0.0019
# Epoch 16/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 74ms/step - loss: 8.5061e-04 - val_loss: 0.0017
# Epoch 17/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 8.4099e-04 - val_loss: 0.0017
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 7.7228e-04 - val_loss: 0.0017
# Epoch 19/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 7.3552e-04 - val_loss: 0.0016
# Epoch 20/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 8.0461e-04 - val_loss: 0.0016
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 7.6083e-04 - val_loss: 0.0015
# Epoch 22/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 7.1781e-04 - val_loss: 0.0015
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 7.1950e-04 - val_loss: 0.0015
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - loss: 7.1016e-04 - val_loss: 0.0014
# Epoch 25/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 6.6818e-04 - val_loss: 0.0014
# Epoch 26/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 6.5831e-04 - val_loss: 0.0014
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 67ms/step - loss: 6.8514e-04 - val_loss: 0.0014
# Epoch 28/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - loss: 6.5566e-04 - val_loss: 0.0013
# Epoch 29/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.2602e-04 - val_loss: 0.0013
# Epoch 30/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 6.7247e-04 - val_loss: 0.0013
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 6.3649e-04 - val_loss: 0.0013
# Epoch 32/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 6.3744e-04 - val_loss: 0.0013
# Epoch 33/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.0100e-04 - val_loss: 0.0013
# Epoch 34/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.2759e-04 - val_loss: 0.0013
# Epoch 35/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.8982e-04 - val_loss: 0.0012
# Epoch 36/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.0756e-04 - val_loss: 0.0012
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.8279e-04 - val_loss: 0.0012
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.8044e-04 - val_loss: 0.0012
# Epoch 39/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 5.7380e-04 - val_loss: 0.0012
# Epoch 40/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 5.9504e-04 - val_loss: 0.0011
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 5.5879e-04 - val_loss: 0.0011
# Epoch 42/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.5349e-04 - val_loss: 0.0011
# Epoch 43/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 5.5453e-04 - val_loss: 0.0011
# Epoch 44/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.8067e-04 - val_loss: 0.0011
# Epoch 45/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 5.7139e-04 - val_loss: 0.0011
# Epoch 46/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.2656e-04 - val_loss: 0.0010
# Epoch 47/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 5.3458e-04 - val_loss: 0.0010
# Epoch 48/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.0907e-04 - val_loss: 0.0010
# Epoch 49/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 5.4855e-04 - val_loss: 0.0010
# Epoch 50/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.8667e-04 - val_loss: 0.0010
# Epoch 51/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.7854e-04 - val_loss: 9.8457e-04
# Epoch 52/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 5.5343e-04 - val_loss: 9.8714e-04
# Epoch 53/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 5.6569e-04 - val_loss: 0.0010
# Epoch 54/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.8948e-04 - val_loss: 9.6594e-04
# Epoch 55/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.2717e-04 - val_loss: 9.6990e-04
# Epoch 56/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.0192e-04 - val_loss: 9.2279e-04
# Epoch 57/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.8126e-04 - val_loss: 9.2187e-04
# Epoch 58/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.8141e-04 - val_loss: 9.3067e-04
# Epoch 59/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 4.5501e-04 - val_loss: 8.9363e-04
# Epoch 60/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.7579e-04 - val_loss: 8.8761e-04
# Epoch 61/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 61ms/step - loss: 4.8645e-04 - val_loss: 8.7194e-04
# Epoch 62/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.6679e-04 - val_loss: 8.5749e-04
# Epoch 63/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.4791e-04 - val_loss: 8.5506e-04
# Epoch 64/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.6528e-04 - val_loss: 8.5003e-04
# Epoch 65/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.5922e-04 - val_loss: 8.5042e-04
# Epoch 66/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.5437e-04 - val_loss: 8.1470e-04
# Epoch 67/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 4.6020e-04 - val_loss: 8.5342e-04
# Epoch 68/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - loss: 4.4609e-04 - val_loss: 8.1610e-04
# Epoch 69/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 4.6268e-04 - val_loss: 8.3349e-04
# Epoch 70/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.6826e-04 - val_loss: 8.1097e-04
# Epoch 71/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 4.3993e-04 - val_loss: 7.8752e-04
# Epoch 72/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 5.2391e-04 - val_loss: 8.5537e-04
# Epoch 73/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 66ms/step - loss: 4.4245e-04 - val_loss: 7.8247e-04
# Epoch 74/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.0126e-04 - val_loss: 7.6334e-04
# Epoch 75/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - loss: 4.2750e-04 - val_loss: 7.6973e-04
# Epoch 76/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.7088e-04 - val_loss: 7.9125e-04
# Epoch 77/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.0833e-04 - val_loss: 7.6153e-04
# Epoch 78/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 3.8881e-04 - val_loss: 7.2942e-04
# Epoch 79/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 4.4316e-04 - val_loss: 7.9540e-04
# Epoch 80/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.5874e-04 - val_loss: 7.2419e-04
# Epoch 81/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 3.8840e-04 - val_loss: 7.1930e-04
# Epoch 82/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.0660e-04 - val_loss: 7.2514e-04
# Epoch 83/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.4161e-04 - val_loss: 7.5393e-04
# Epoch 84/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.0174e-04 - val_loss: 7.3708e-04
# Epoch 85/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - loss: 3.9692e-04 - val_loss: 7.3876e-04
# Epoch 86/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 4.2165e-04 - val_loss: 7.0329e-04
# Epoch 87/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 3.7830e-04 - val_loss: 6.8142e-04
# Epoch 88/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step - loss: 3.7726e-04 - val_loss: 6.8532e-04
# Epoch 89/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.3919e-04 - val_loss: 7.2199e-04
# Epoch 90/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 4.1229e-04 - val_loss: 6.9542e-04
# Epoch 91/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 3.9468e-04 - val_loss: 7.0283e-04
# Epoch 92/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - loss: 4.3366e-04 - val_loss: 6.7723e-04
# Epoch 93/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 5s 65ms/step - loss: 3.8162e-04 - val_loss: 6.7193e-04
# Epoch 94/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.5897e-04 - val_loss: 6.5106e-04
# Epoch 95/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.8297e-04 - val_loss: 6.7113e-04
# Epoch 96/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 3.8165e-04 - val_loss: 6.3964e-04
# Epoch 97/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.9663e-04 - val_loss: 6.6446e-04
# Epoch 98/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 39ms/step - loss: 3.5343e-04 - val_loss: 6.4234e-04
# Epoch 99/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 3.6559e-04 - val_loss: 6.2916e-04
# Epoch 100/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 3.9841e-04 - val_loss: 6.3339e-04
# optimal loss: 0.000629
#
# === best model: {'units': 64, 'dropout': 0.1, 'lr': 0.001}, val loss: 0.000591 ===

# %%
results = {}
y_pred_scaled = best_model_1.predict(X_test)
y_test_scaled = y_test.reshape(-1, 1)

y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test_scaled)

mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
results["LSTM"] = (mae, rmse)

print("========== Final Results ==========")
print(f"Test MAE : {mae:.6f}")
print(f"Test RMSE: {rmse:.6f}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# ========== Final Results ==========
# Test MAE : 0.000546
# Test RMSE: 0.000791

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))
plt.plot(y_true, label="Actual Volatility", linewidth=2)
plt.plot(y_pred, label="Predicted Volatility", linewidth=2)
plt.title("Actual vs Predicted (Model 1)")
plt.xlabel("Time (test period)")
plt.ylabel("Volatility")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Model 2 : Predict Realized Volatility using LSTM + GARCH

# %%
# ================================
# 4. LSTM용 데이터셋 만들기
#    - feature: ret, lag_realized_vol, garch_vol_pred
#    - target: realized_vol
#    - 시퀀스: lookback 길이
# ================================

feature_cols = ["ret", "lag_realized_vol", "garch_vol_pred"]  # 필요에 따라 빼고/추가
target_col = "realized_vol"
lookback = 22

data = df.copy()

X_raw = data[feature_cols].values
y_raw = data[target_col].values.reshape(-1, 1)

n = len(X_raw)
n_train = int(n * 0.7)
n_val = int(n * 0.15)

X_raw_train = X_raw[:n_train]
X_raw_val   = X_raw[n_train:n_train + n_val]
X_raw_test  = X_raw[n_train + n_val:]

y_raw_train = y_raw[:n_train]
y_raw_val   = y_raw[n_train:n_train + n_val]
y_raw_test  = y_raw[n_train + n_val:]

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_raw_train)
y_train_scaled = scaler_y.fit_transform(y_raw_train)

X_val_scaled   = scaler_X.transform(X_raw_val)
y_val_scaled   = scaler_y.transform(y_raw_val)

X_test_scaled  = scaler_X.transform(X_raw_test)
y_test_scaled  = scaler_y.transform(y_raw_test)

# Train
X_train_list = []
y_train_list = []
for i in range(lookback, len(X_train_scaled)):
    X_train_list.append(X_train_scaled[i - lookback:i])
    y_train_list.append(y_train_scaled[i, 0])
X_train = np.array(X_train_list)
y_train = np.array(y_train_list)

# Val
X_val_list = []
y_val_list = []
for i in range(lookback, len(X_val_scaled)):
    X_val_list.append(X_val_scaled[i - lookback:i])
    y_val_list.append(y_val_scaled[i, 0])
X_val = np.array(X_val_list)
y_val = np.array(y_val_list)

# Test
X_test_list = []
y_test_list = []
for i in range(lookback, len(X_test_scaled)):
    X_test_list.append(X_test_scaled[i - lookback:i])
    y_test_list.append(y_test_scaled[i, 0])
X_test = np.array(X_test_list)
y_test = np.array(y_test_list)


print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape, y_val.shape)
print("Test :", X_test.shape, y_test.shape)
# Out:
# Train: (3312, 22, 3) (3312,)
# Val  : (692, 22, 3) (692,)
# Test : (694, 22, 3) (694,)

# %%
# ================================
# 6. LSTM 모델 정의 & 학습
# ================================

input_shape = X_train.shape[1:]  # (lookback, n_features)
print("LSTM input shape:", input_shape)

lstm_units   = best_cfg_1["units"]
dropout_rate = best_cfg_1["dropout"]
learning_rate = best_cfg_1["lr"]
num_layers = 2

model = models.Sequential()
# 첫 번째 LSTM
model.add(
    layers.LSTM(
        lstm_units,
        activation="tanh",
        return_sequences=(num_layers > 1),
        input_shape=input_shape,
    )
)
model.add(layers.Dropout(dropout_rate))

# 두 번째 LSTM (layer=2)
model.add(
    layers.LSTM(
        lstm_units,
        activation="tanh",
        return_sequences=False,
    )
)
model.add(layers.Dropout(dropout_rate))

# 출력층
model.add(layers.Dense(1, activation="relu"))

model.compile(
    loss="mse",
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
)

print(model.summary())

es = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=10,
    restore_best_weights=True,
)

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=64,
    shuffle=False,
    callbacks=[es],
    verbose=1,
)
# Out:
# LSTM input shape: (22, 3)
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_8 (LSTM)                   │ (None, 22, 64)         │        17,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 22, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_9 (LSTM)                   │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,497 (197.25 KB)
#  Trainable params: 50,497 (197.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0084 - val_loss: 0.0089
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030 - val_loss: 0.0050
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0020 - val_loss: 0.0045
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0017 - val_loss: 0.0029
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 36ms/step - loss: 0.0015 - val_loss: 0.0019
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - loss: 0.0011 - val_loss: 0.0015
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 9.6199e-04 - val_loss: 0.0015
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 9.0518e-04 - val_loss: 0.0015
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 8.3448e-04 - val_loss: 0.0015
# Epoch 12/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 7.5628e-04 - val_loss: 0.0015
# Epoch 13/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 7.7366e-04 - val_loss: 0.0016
# Epoch 14/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 7.5345e-04 - val_loss: 0.0014
# Epoch 15/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 7.8968e-04 - val_loss: 0.0015
# Epoch 16/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.8016e-04 - val_loss: 0.0015
# Epoch 17/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 7.3827e-04 - val_loss: 0.0016
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.4796e-04 - val_loss: 0.0013
# Epoch 19/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 6.8900e-04 - val_loss: 0.0014
# Epoch 20/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.5462e-04 - val_loss: 0.0014
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.5978e-04 - val_loss: 0.0014
# Epoch 22/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - loss: 7.5607e-04 - val_loss: 0.0014
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.2258e-04 - val_loss: 0.0014
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.9023e-04 - val_loss: 0.0013
# Epoch 25/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.7246e-04 - val_loss: 0.0014
# Epoch 26/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 6.2065e-04 - val_loss: 0.0014
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.1473e-04 - val_loss: 0.0013
# Epoch 28/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 6.6088e-04 - val_loss: 0.0014
# Epoch 29/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.8462e-04 - val_loss: 0.0013
# Epoch 30/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.6457e-04 - val_loss: 0.0013
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 6.1443e-04 - val_loss: 0.0013
# Epoch 32/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.4106e-04 - val_loss: 0.0012
# Epoch 33/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 5.4979e-04 - val_loss: 0.0013
# Epoch 34/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 5.7946e-04 - val_loss: 0.0013
# Epoch 35/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.3195e-04 - val_loss: 0.0012
# Epoch 36/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 5.7124e-04 - val_loss: 0.0012
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.7814e-04 - val_loss: 0.0012
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.8378e-04 - val_loss: 0.0012
# Epoch 39/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.1573e-04 - val_loss: 0.0011
# Epoch 40/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 5.7260e-04 - val_loss: 0.0011
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 5.5018e-04 - val_loss: 0.0011
# Epoch 42/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.6925e-04 - val_loss: 0.0011
# Epoch 43/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 5.1485e-04 - val_loss: 0.0011
# Epoch 44/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.6957e-04 - val_loss: 0.0011
# Epoch 45/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.9691e-04 - val_loss: 0.0012
# Epoch 46/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 5.4386e-04 - val_loss: 0.0010
# Epoch 47/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.8765e-04 - val_loss: 0.0011
# Epoch 48/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.9577e-04 - val_loss: 9.7180e-04
# Epoch 49/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.0946e-04 - val_loss: 9.5763e-04
# Epoch 50/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 5.1251e-04 - val_loss: 0.0010
# Epoch 51/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.6570e-04 - val_loss: 0.0010
# Epoch 52/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 5.0061e-04 - val_loss: 0.0010
# Epoch 53/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 3s 33ms/step - loss: 4.5494e-04 - val_loss: 9.9977e-04
# Epoch 54/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.4236e-04 - val_loss: 0.0010
# Epoch 55/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 4.4807e-04 - val_loss: 9.3773e-04
# Epoch 56/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.4903e-04 - val_loss: 0.0010
# Epoch 57/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.9423e-04 - val_loss: 0.0011
# Epoch 58/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7243e-04 - val_loss: 0.0011
# Epoch 59/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.0322e-04 - val_loss: 0.0011
# Epoch 60/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.6461e-04 - val_loss: 8.8653e-04
# Epoch 61/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.0480e-04 - val_loss: 0.0010
# Epoch 62/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.5881e-04 - val_loss: 0.0011
# Epoch 63/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.3291e-04 - val_loss: 7.6603e-04
# Epoch 64/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.9982e-04 - val_loss: 8.4053e-04
# Epoch 65/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.5156e-04 - val_loss: 0.0010
# Epoch 66/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.0452e-04 - val_loss: 7.0717e-04
# Epoch 67/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.2606e-04 - val_loss: 8.4716e-04
# Epoch 68/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.7349e-04 - val_loss: 9.9512e-04
# Epoch 69/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.3330e-04 - val_loss: 8.6720e-04
# Epoch 70/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.2382e-04 - val_loss: 8.1030e-04
# Epoch 71/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9090e-04 - val_loss: 8.1462e-04
# Epoch 72/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 3.9532e-04 - val_loss: 7.8053e-04
# Epoch 73/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.7890e-04 - val_loss: 7.3342e-04
# Epoch 74/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 3.4585e-04 - val_loss: 7.9530e-04
# Epoch 75/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.0772e-04 - val_loss: 7.5296e-04
# Epoch 76/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7814e-04 - val_loss: 7.2078e-04

# %%
y_pred_scaled = model.predict(X_test)
y_test_scaled = y_test.reshape(-1, 1)

y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test_scaled)

mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
results["LSTM-GARCH"] = (mae, rmse)


print("========== Final Results ==========")
print(f"Test MAE : {mae:.6f}")
print(f"Test RMSE: {rmse:.6f}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# ========== Final Results ==========
# Test MAE : 0.000605
# Test RMSE: 0.000839

# %%
plt.figure(figsize=(14, 6))
plt.plot(y_true, label="Actual Volatility", linewidth=2)
plt.plot(y_pred, label="Predicted Volatility", linewidth=2)
plt.title("Actual vs Predicted (Model 2)")
plt.xlabel("Time (test period)")
plt.ylabel("Volatility")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Model 3 : Predict Realized Volatility using LSTM + GARCH + VIX

# %%
# ================================
# 4. LSTM용 데이터셋 만들기
#    - feature: ret, lag_realized_vol, garch_vol_pred, VIX
#    - target: realized_vol
#    - 시퀀스: lookback 길이
# ================================

feature_cols = ["ret", "lag_realized_vol", "garch_vol_pred", "VIX"]  # 필요에 따라 빼고/추가
target_col = "realized_vol"
lookback = 22

data = df.copy()

X_raw = data[feature_cols].values
y_raw = data[target_col].values.reshape(-1, 1)

n = len(X_raw)
n_train = int(n * 0.7)
n_val = int(n * 0.15)

X_raw_train = X_raw[:n_train]
X_raw_val   = X_raw[n_train:n_train + n_val]
X_raw_test  = X_raw[n_train + n_val:]

y_raw_train = y_raw[:n_train]
y_raw_val   = y_raw[n_train:n_train + n_val]
y_raw_test  = y_raw[n_train + n_val:]

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_train_scaled = scaler_X.fit_transform(X_raw_train)
y_train_scaled = scaler_y.fit_transform(y_raw_train)

X_val_scaled   = scaler_X.transform(X_raw_val)
y_val_scaled   = scaler_y.transform(y_raw_val)

X_test_scaled  = scaler_X.transform(X_raw_test)
y_test_scaled  = scaler_y.transform(y_raw_test)

# Train
X_train_list = []
y_train_list = []
for i in range(lookback, len(X_train_scaled)):
    X_train_list.append(X_train_scaled[i - lookback:i])
    y_train_list.append(y_train_scaled[i, 0])
X_train = np.array(X_train_list)
y_train = np.array(y_train_list)

# Val
X_val_list = []
y_val_list = []
for i in range(lookback, len(X_val_scaled)):
    X_val_list.append(X_val_scaled[i - lookback:i])
    y_val_list.append(y_val_scaled[i, 0])
X_val = np.array(X_val_list)
y_val = np.array(y_val_list)

# Test
X_test_list = []
y_test_list = []
for i in range(lookback, len(X_test_scaled)):
    X_test_list.append(X_test_scaled[i - lookback:i])
    y_test_list.append(y_test_scaled[i, 0])
X_test = np.array(X_test_list)
y_test = np.array(y_test_list)


print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape, y_val.shape)
print("Test :", X_test.shape, y_test.shape)
# Out:
# Train: (3312, 22, 4) (3312,)
# Val  : (692, 22, 4) (692,)
# Test : (694, 22, 4) (694,)

# %%
# ================================
# 6. LSTM 모델 정의 & 학습
# ================================

input_shape = X_train.shape[1:]  # (lookback, n_features)
print("LSTM 입력 형태:", input_shape)

lstm_units   = best_cfg_1["units"]
dropout_rate = best_cfg_1["dropout"]
learning_rate = best_cfg_1["lr"]
num_layers = 2

model = models.Sequential()
# 첫 번째 LSTM
model.add(
    layers.LSTM(
        lstm_units,
        activation="tanh",
        return_sequences=(num_layers > 1),
        input_shape=input_shape,
    )
)
model.add(layers.Dropout(dropout_rate))

# 두 번째 LSTM (num_layers=2 기준)
model.add(
    layers.LSTM(
        lstm_units,
        activation="tanh",
        return_sequences=False,
    )
)
model.add(layers.Dropout(dropout_rate))

# 출력층
model.add(layers.Dense(1, activation="relu"))

model.compile(
    loss="mse",
    optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
)

print(model.summary())

es = callbacks.EarlyStopping( 
    monitor="val_loss",
    patience=10,
    restore_best_weights=True,
)

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=100,
    batch_size=64,
    shuffle=False,
    callbacks=[es],
    verbose=1,
)
# Out:
# LSTM 입력 형태: (22, 4)
# c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_10 (LSTM)                  │ (None, 22, 64)         │        17,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 22, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_11 (LSTM)                  │ (None, 64)             │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,753 (198.25 KB)
#  Trainable params: 50,753 (198.25 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - loss: 0.0053 - val_loss: 0.0046
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0018 - val_loss: 0.0028
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0016 - val_loss: 0.0028
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0013 - val_loss: 0.0020
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0012 - val_loss: 0.0019
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0011 - val_loss: 0.0018
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.4875e-04 - val_loss: 0.0018
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 8.2408e-04 - val_loss: 0.0018
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 7.9690e-04 - val_loss: 0.0018
# Epoch 11/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.5600e-04 - val_loss: 0.0018
# Epoch 12/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 7.1227e-04 - val_loss: 0.0019
# Epoch 13/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.5709e-04 - val_loss: 0.0017
# Epoch 14/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.7546e-04 - val_loss: 0.0020
# Epoch 15/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.0207e-04 - val_loss: 0.0017
# Epoch 16/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 7.4220e-04 - val_loss: 0.0017
# Epoch 17/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.6554e-04 - val_loss: 0.0017
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.9328e-04 - val_loss: 0.0017
# Epoch 19/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.7606e-04 - val_loss: 0.0017
# Epoch 20/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.9574e-04 - val_loss: 0.0015
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.7309e-04 - val_loss: 0.0017
# Epoch 22/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.2833e-04 - val_loss: 0.0016
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.0089e-04 - val_loss: 0.0016
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.8173e-04 - val_loss: 0.0017
# Epoch 25/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.9345e-04 - val_loss: 0.0016
# Epoch 26/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.8709e-04 - val_loss: 0.0014
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3284e-04 - val_loss: 0.0017
# Epoch 28/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.6988e-04 - val_loss: 0.0017
# Epoch 29/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.7269e-04 - val_loss: 0.0016
# Epoch 30/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.1245e-04 - val_loss: 0.0018
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 7.4276e-04 - val_loss: 0.0014
# Epoch 32/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.3996e-04 - val_loss: 0.0014
# Epoch 33/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.4550e-04 - val_loss: 0.0014
# Epoch 34/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.6931e-04 - val_loss: 0.0015
# Epoch 35/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.5308e-04 - val_loss: 0.0014
# Epoch 36/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.5230e-04 - val_loss: 0.0013
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 6.0240e-04 - val_loss: 0.0015
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.4556e-04 - val_loss: 0.0013
# Epoch 39/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.5075e-04 - val_loss: 0.0014
# Epoch 40/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.3635e-04 - val_loss: 0.0013
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.4523e-04 - val_loss: 0.0013
# Epoch 42/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.3316e-04 - val_loss: 0.0013
# Epoch 43/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 5.2123e-04 - val_loss: 0.0014
# Epoch 44/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.2087e-04 - val_loss: 0.0014
# Epoch 45/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 4.8840e-04 - val_loss: 0.0013
# Epoch 46/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.9026e-04 - val_loss: 0.0012
# Epoch 47/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.6830e-04 - val_loss: 0.0014
# Epoch 48/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 4.7400e-04 - val_loss: 0.0013
# Epoch 49/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.1121e-04 - val_loss: 0.0011
# Epoch 50/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 5.0905e-04 - val_loss: 0.0013
# Epoch 51/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.5304e-04 - val_loss: 0.0013
# Epoch 52/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.5073e-04 - val_loss: 0.0011
# Epoch 53/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 4.7762e-04 - val_loss: 0.0013
# Epoch 54/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 5.2897e-04 - val_loss: 0.0012
# Epoch 55/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.9634e-04 - val_loss: 0.0013
# Epoch 56/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 4.7031e-04 - val_loss: 0.0011
# Epoch 57/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.6319e-04 - val_loss: 0.0011
# Epoch 58/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 4.9006e-04 - val_loss: 0.0011
# Epoch 59/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 4.5522e-04 - val_loss: 0.0013

# %%
y_pred_scaled = model.predict(X_test)
y_test_scaled = y_test.reshape(-1, 1)

y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test_scaled)

mae = mean_absolute_error(y_true, y_pred)
mse = mean_squared_error(y_true, y_pred)
rmse = np.sqrt(mse)
results["Hybrid+VIX"] = (mae, rmse)

print("========== Final Results ==========")
print(f"Test MAE : {mae:.6f}")
print(f"Test RMSE: {rmse:.6f}")
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# ========== Final Results ==========
# Test MAE : 0.000699
# Test RMSE: 0.000949

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 6))
plt.plot(y_true, label="Actual Volatility", linewidth=2)
plt.plot(y_pred, label="Predicted Volatility", linewidth=2)
plt.title("Actual vs Predicted (Model 3)")
plt.xlabel("Time (test period)")
plt.ylabel("Volatility")
plt.legend()
plt.grid(True)
plt.show()

# %%
result_table = pd.DataFrame(results, index=["MAE", "RMSE"]).T
print(result_table)
# Out:
#                  MAE      RMSE
# LSTM        0.000546  0.000791
# LSTM-GARCH  0.000605  0.000839
# Hybrid+VIX  0.000699  0.000949

# %%
# ===============================
